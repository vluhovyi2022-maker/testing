# %%
from datetime import datetime
name = "Volodymyr"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Volodymyr start programming at 2025-10-23 19:41:48.228857. Lviv is the best city!
